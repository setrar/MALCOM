# %% [markdown]
# # Deep Convolutional GAN (DC-GAN)

# %%
using Base.Iterators: partition
using Flux
using Flux.Optimise: update!
using Flux.Losses: logitbinarycrossentropy
using Images
using MLDatasets
using Statistics
using Printf
using Random
using CUDA
CUDA.allowscalar(true)

# %%
Base.@kwdef struct HyperParams
    batch_size::Int = 128
    latent_dim::Int = 100
    # epochs::Int = 20
    epochs::Int = 1
    verbose_freq::Int = 1000
    output_x::Int = 6
    output_y::Int = 6
    lr_dscr::Float32 = 0.0002
    lr_gen::Float32 = 0.0002
end
# Out:
# HyperParams

# %%
function create_output_image(gen, fixed_noise, hparams)
    fake_images = @. cpu(gen(fixed_noise))
    image_array = reduce(vcat, reduce.(hcat, partition(fake_images, hparams.output_y)))
    image_array = permutedims(dropdims(image_array; dims=(3, 4)), (2, 1))
    image_array = @. Gray(image_array + 1f0) / 2f0
    return image_array
end
# Out:
# create_output_image (generic function with 1 method)

# %%
function Discriminator()
    return Chain(
            Conv((4, 4), 1 => 64; stride = 2, pad = 1, init = dcgan_init),
            x->leakyrelu.(x, 0.2f0),
            Dropout(0.25),
            Conv((4, 4), 64 => 128; stride = 2, pad = 1, init = dcgan_init),
            x->leakyrelu.(x, 0.2f0),
            Dropout(0.25), 
            x->reshape(x, 7 * 7 * 128, :),
            Dense(7 * 7 * 128, 1))	
end
# Out:
# Discriminator (generic function with 1 method)

# %%
function Generator(latent_dim::Int)
    return Chain(
            Dense(latent_dim, 7 * 7 * 256),
            BatchNorm(7 * 7 * 256, relu),
            x->reshape(x, 7, 7, 256, :),
            ConvTranspose((5, 5), 256 => 128; stride = 1, pad = 2, init = dcgan_init),
            BatchNorm(128, relu),
            ConvTranspose((4, 4), 128 => 64; stride = 2, pad = 1, init = dcgan_init),
            BatchNorm(64, relu),
            ConvTranspose((4, 4), 64 => 1; stride = 2, pad = 1, init = dcgan_init),
            x -> tanh.(x)
            )
end
# Out:
# Generator (generic function with 1 method)

# %%
# Loss functions
function discriminator_loss(real_output, fake_output)
    real_loss = logitbinarycrossentropy(real_output, 1)
    fake_loss = logitbinarycrossentropy(fake_output, 0)
    return real_loss + fake_loss
end
# Out:
# discriminator_loss (generic function with 1 method)

# %%
function train_discriminator!(gen, dscr, x, opt_dscr, hparams)
    noise = randn!(similar(x, (hparams.latent_dim, hparams.batch_size))) 
    fake_input = gen(noise)
    # Taking gradient
    loss, grads = Flux.withgradient(dscr) do dscr
        discriminator_loss(dscr(x), dscr(fake_input))
    end
    update!(opt_dscr, dscr, grads[1])
    return loss
end
# Out:
# train_discriminator! (generic function with 1 method)

# %%
function train_generator!(gen, dscr, x, opt_gen, hparams)
    noise = randn!(similar(x, (hparams.latent_dim, hparams.batch_size))) 
    # Taking gradient
    loss, grads = Flux.withgradient(gen) do gen
        generator_loss(dscr(gen(noise)))
    end
    update!(opt_gen, gen, grads[1])
    return loss
end
# Out:
# train_generator! (generic function with 1 method)

# %%
function train(; kws...)
    # Model Parameters
    hparams = HyperParams(; kws...)

    if CUDA.functional()
        @info "Training on GPU"
    else
        @warn "Training on CPU, this will be very slow!"  # 20 mins/epoch
    end

    # Load MNIST dataset
    images = MLDatasets.MNIST(:train).features
    # Normalize to [-1, 1]
    image_tensor = reshape(@.(2f0 * images - 1f0), 28, 28, 1, :)
    # Partition into batches
    data = [image_tensor[:, :, :, r] |> gpu for r in partition(1:60000, hparams.batch_size)]

    fixed_noise = [randn(Float32, hparams.latent_dim, 1) |> gpu for _=1:hparams.output_x*hparams.output_y]

    # Discriminator
    dscr = Discriminator() |> gpu

    # Generator
    gen =  Generator(hparams.latent_dim) |> gpu

    # Optimizers
    opt_dscr = Flux.setup(Adam(hparams.lr_dscr), dscr)
    opt_gen = Flux.setup(Adam(hparams.lr_gen), gen)

    # Training
    train_steps = 0
    for ep in 1:hparams.epochs
        @info "Epoch $ep"
        for x in data
            # Update discriminator and generator
            loss_dscr = train_discriminator!(gen, dscr, x, opt_dscr, hparams)
            loss_gen = train_generator!(gen, dscr, x, opt_gen, hparams)

            if train_steps % hparams.verbose_freq == 0
                @info("Train step $(train_steps), Discriminator loss = $(loss_dscr), Generator loss = $(loss_gen)")
                # Save generated fake image
                output_image = create_output_image(gen, fixed_noise, hparams)
                save(@sprintf("images/dcgan_steps_%06d.png", train_steps), output_image)
            end
            train_steps += 1
        end
    end

    output_image = create_output_image(gen, fixed_noise, hparams)
    save(@sprintf("images/dcgan_steps_%06d.png", train_steps), output_image)
end
# Out:
# train (generic function with 1 method)

# %%
# weight initialization as given in the paper https://arxiv.org/abs/1511.06434
dcgan_init(shape...) = randn(Float32, shape...) * 0.02f0

generator_loss(fake_output) = logitbinarycrossentropy(fake_output, 1)

# if abspath(PROGRAM_FILE) == @__FILE__
    train()
# end
# Out:
# ┌ Warning: Training on CPU, this will be very slow!
# └ @ Main In[9]:8
# ┌ Info: The CUDA function is being called but CUDA.jl is not functional.
# └ Defaulting back to the CPU. (No action is required if you want to run on the CPU).
# [ Info: Epoch 1
# [ Info: Train step 0, Discriminator loss = 1.3771783, Generator loss = 0.68713003
# TaskFailedException
#
#     nested task error: TaskFailedException
#
#         nested task error: InterruptException:
#         Stacktrace:
#          [1] col2im!(x::SubArray{Float32, 4, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Int64}, true}, col::SubArray{Float32, 2, Array{Float32, 3}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Int64}, true}, cdims::DenseConvDims{3, 3, 3, 6, 3}, beta::Float32)
#            @ NNlib ~/.julia/packages/NNlib/O0zGY/src/impl/conv_im2col.jl:290
#          [2] (::NNlib.var"#652#653"{Float32, Array{Float32, 3}, Float32, Float32, SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}}, true}, DenseConvDims{3, 3, 3, 6, 3}, Int64, Int64, Int64, UnitRange{Int64}, Int64})()
#            @ NNlib ~/.julia/packages/NNlib/O0zGY/src/impl/conv_im2col.jl:165
#     Stacktrace:
#      [1] sync_end(c::Channel{Any})
#        @ Base ./task.jl:448
#      [2] macro expansion
#        @ ./task.jl:480 [inlined]
#      [3] ∇conv_data_im2col!(dx::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, dy::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, w::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}}, true}, cdims::DenseConvDims{3, 3, 3, 6, 3}; col::Array{Float32, 3}, alpha::Float32, beta::Float32, ntasks::Int64)
#        @ NNlib ~/.julia/packages/NNlib/O0zGY/src/impl/conv_im2col.jl:155
#      [4] ∇conv_data_im2col!(dx::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, dy::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, w::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}}, true}, cdims::DenseConvDims{3, 3, 3, 6, 3})
#        @ NNlib ~/.julia/packages/NNlib/O0zGY/src/impl/conv_im2col.jl:126
#      [5] (::NNlib.var"#324#328"{@Kwargs{}, DenseConvDims{3, 3, 3, 6, 3}, SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}}, true}, SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}})()
#        @ NNlib ~/.julia/packages/NNlib/O0zGY/src/conv.jl:253
#
# Stacktrace:
#   [1] sync_end(c::Channel{Any})
#     @ Base ./task.jl:448
#   [2] macro expansion
#     @ ./task.jl:480 [inlined]
#   [3] ∇conv_data!(out::Array{Float32, 5}, in1::Array{Float32, 5}, in2::Array{Float32, 5}, cdims::DenseConvDims{3, 3, 3, 6, 3}; kwargs::@Kwargs{})
#     @ NNlib ~/.julia/packages/NNlib/O0zGY/src/conv.jl:249
#   [4] ∇conv_data!
#     @ ~/.julia/packages/NNlib/O0zGY/src/conv.jl:226 [inlined]
#   [5] ∇conv_data!(y::Array{Float32, 4}, x::Array{Float32, 4}, w::Array{Float32, 4}, cdims::DenseConvDims{2, 2, 2, 4, 2}; kwargs::@Kwargs{})
#     @ NNlib ~/.julia/packages/NNlib/O0zGY/src/conv.jl:145
#   [6] ∇conv_data!
#     @ ~/.julia/packages/NNlib/O0zGY/src/conv.jl:140 [inlined]
#   [7] #∇conv_data#242
#     @ ~/.julia/packages/NNlib/O0zGY/src/conv.jl:99 [inlined]
#   [8] ∇conv_data
#     @ ~/.julia/packages/NNlib/O0zGY/src/conv.jl:95 [inlined]
#   [9] #381
#     @ ~/.julia/packages/NNlib/O0zGY/src/conv.jl:350 [inlined]
#  [10] unthunk
#     @ ~/.julia/packages/ChainRulesCore/zgT0R/src/tangent_types/thunks.jl:204 [inlined]
#  [11] wrap_chainrules_output
#     @ ~/.julia/packages/Zygote/jxHJc/src/compiler/chainrules.jl:110 [inlined]
#  [12] map
#     @ ./tuple.jl:293 [inlined]
#  [13] map
#     @ ./tuple.jl:294 [inlined]
#  [14] wrap_chainrules_output
#     @ ~/.julia/packages/Zygote/jxHJc/src/compiler/chainrules.jl:111 [inlined]
#  [15] ZBack
#     @ ~/.julia/packages/Zygote/jxHJc/src/compiler/chainrules.jl:211 [inlined]
#  [16] Conv
#     @ ~/.julia/packages/Flux/Wz6D4/src/layers/conv.jl:202 [inlined]
#  [17] (::Zygote.Pullback{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, Array{Float32, 4}}}, Zygote.ZBack{Flux.var"#187#188"}, Zygote.Pullback{Tuple{typeof(Base.Broadcast.materialize), Array{Float32, 4}}, Tuple{}}, Zygote.var"#3748#back#1183"{Zygote.var"#1177#1181"{Tuple{Array{Float32, 4}, Array{Float32, 4}}}}, Zygote.ZBack{Flux.var"#_conv_size_check_pullback#264"}, Zygote.var"#3892#back#1249"{Zygote.var"#1245#1248"}, Zygote.ZBack{NNlib.var"#conv_pullback#383"{@Kwargs{}, Array{Float32, 4}, Array{Float32, 4}, DenseConvDims{2, 2, 2, 4, 2}}}, Zygote.ZBack{Flux.var"#conv_dims_pullback#249"}, Zygote.Pullback{Tuple{typeof(NNlib.fast_act), typeof(identity), Array{Float32, 4}}, Tuple{}}, Zygote.Pullback{Tuple{typeof(Flux.conv_reshape_bias), Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:bias, Zygote.Context{false}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, Vector{Float32}}}, Zygote.Pullback{Tuple{typeof(Flux.conv_reshape_bias), Vector{Float32}, Tuple{Int64, Int64}}, Tuple{Zygote.var"#2169#back#293"{Zygote.var"#291#292"{Tuple{Tuple{Nothing}, Tuple{Nothing, Nothing}, Tuple{Nothing, Nothing}}, Zygote.var"#2763#back#609"{Zygote.var"#603#607"{Vector{Float32}, Tuple{Int64, Int64, Colon, Int64}}}}}, Zygote.var"#2013#back#204"{typeof(identity)}, Zygote.var"#2013#back#204"{typeof(identity)}, Zygote.var"#2210#back#313"{Zygote.Jnew{Flux.var"#241#242", Nothing, false}}, Zygote.var"#2845#back#673"{Zygote.var"#map_back#667"{Flux.var"#241#242", 1, Tuple{Tuple{Int64, Int64}}, Tuple{Val{2}}, Tuple{Tuple{Int64, Zygote.Pullback{Tuple{Flux.var"#241#242", Int64}, Tuple{}}}, Tuple{Int64, Zygote.Pullback{Tuple{Flux.var"#241#242", Int64}, Tuple{}}}}}}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:stride, Zygote.Context{false}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, Tuple{Int64, Int64}}}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:σ, Zygote.Context{false}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, typeof(identity)}}}})(Δ::Array{Float32, 4})
#     @ Zygote ~/.julia/packages/Zygote/jxHJc/src/compiler/interface2.jl:0
#  [18] macro expansion
#     @ ~/.julia/packages/Flux/Wz6D4/src/layers/basic.jl:53 [inlined]
#  [19] _applychain
#     @ ~/.julia/packages/Flux/Wz6D4/src/layers/basic.jl:53 [inlined]
#  [20] (::Zygote.Pullback{Tuple{typeof(Flux._applychain), Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}, Array{Float32, 4}}, Tuple{Zygote.Pullback{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:σ, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, typeof(identity)}}, Zygote.Pullback{Tuple{typeof(NNlib.fast_act), typeof(identity), Matrix{Float32}}, Tuple{}}, Zygote.var"#3748#back#1183"{Zygote.var"#1177#1181"{Tuple{Matrix{Float32}, Vector{Float32}}}}, Zygote.var"#3892#back#1249"{Zygote.var"#1245#1248"}, Zygote.ZBack{Flux.var"#_size_check_pullback#210"{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}, Pair{Int64, Int64}}}}, Zygote.ZBack{ChainRules.var"#times_pullback#1464"{Matrix{Float32}, Matrix{Float32}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:bias, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Vector{Float32}}}, Zygote.Pullback{Tuple{typeof(Base.Broadcast.materialize), Matrix{Float32}}, Tuple{}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}}, Zygote.Pullback{Tuple{Type{Pair}, Int64, Int64}, Any}, Zygote.ZBack{ChainRules.var"#size_pullback#919"}, Zygote.ZBack{Flux.var"#187#188"}}}, Zygote.Pullback{Tuple{var"#4#7", Array{Float32, 4}}, Tuple{Zygote.ZBack{ChainRules.var"#times_pullback3#1330"{Int64, Int64, Int64}}, Zygote.var"#2763#back#609"{Zygote.var"#603#607"{Array{Float32, 4}, Tuple{Int64, Colon}}}}}, Zygote.var"#2029#back#213"{Zygote.var"#back#211"{8, 3, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}}}, Zygote.Pullback{Tuple{Dropout{Float64, Colon, TaskLocalRNG}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:rng, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, TaskLocalRNG}}, Zygote.var"#2013#back#204"{typeof(identity)}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:dims, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, Colon}}, Zygote.ZBack{ChainRules.var"#times_pullback2#1329"{Float64, Bool}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:dims,)}}, Tuple{Colon}}, Tuple{Zygote.var"#2220#back#315"{Zygote.Jnew{@NamedTuple{dims::Colon}, Nothing, true}}}}, Zygote.Pullback{Tuple{typeof(Flux._isactive), Dropout{Float64, Colon, TaskLocalRNG}, Array{Float32, 4}}, Any}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:p, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, Float64}}, Zygote.var"#kw_zpullback#53"{NNlib.var"#dropout_back#200"{Float64, Array{Float32, 4}, Float32}}}}, Zygote.var"#2029#back#213"{Zygote.var"#back#211"{8, 8, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}, Zygote.Pullback{Tuple{Dropout{Float64, Colon, TaskLocalRNG}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:rng, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, TaskLocalRNG}}, Zygote.var"#2013#back#204"{typeof(identity)}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:dims, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, Colon}}, Zygote.ZBack{ChainRules.var"#times_pullback2#1329"{Float64, Bool}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:dims,)}}, Tuple{Colon}}, Tuple{Zygote.var"#2220#back#315"{Zygote.Jnew{@NamedTuple{dims::Colon}, Nothing, true}}}}, Zygote.Pullback{Tuple{typeof(Flux._isactive), Dropout{Float64, Colon, TaskLocalRNG}, Array{Float32, 4}}, Any}, Zygot ...
#     @ Zygote ~/.julia/packages/Zygote/jxHJc/src/compiler/interface2.jl:0
#  [21] Chain
#     @ ~/.julia/packages/Flux/Wz6D4/src/layers/basic.jl:51 [inlined]
#  [22] (::Zygote.Pullback{Tuple{Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:layers, Zygote.Context{false}, Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}, Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}}, Zygote.Pullback{Tuple{typeof(Flux._applychain), Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}, Array{Float32, 4}}, Tuple{Zygote.Pullback{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:σ, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, typeof(identity)}}, Zygote.Pullback{Tuple{typeof(NNlib.fast_act), typeof(identity), Matrix{Float32}}, Tuple{}}, Zygote.var"#3748#back#1183"{Zygote.var"#1177#1181"{Tuple{Matrix{Float32}, Vector{Float32}}}}, Zygote.var"#3892#back#1249"{Zygote.var"#1245#1248"}, Zygote.ZBack{Flux.var"#_size_check_pullback#210"{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}, Pair{Int64, Int64}}}}, Zygote.ZBack{ChainRules.var"#times_pullback#1464"{Matrix{Float32}, Matrix{Float32}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:bias, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Vector{Float32}}}, Zygote.Pullback{Tuple{typeof(Base.Broadcast.materialize), Matrix{Float32}}, Tuple{}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}}, Zygote.Pullback{Tuple{Type{Pair}, Int64, Int64}, Any}, Zygote.ZBack{ChainRules.var"#size_pullback#919"}, Zygote.ZBack{Flux.var"#187#188"}}}, Zygote.Pullback{Tuple{var"#4#7", Array{Float32, 4}}, Tuple{Zygote.ZBack{ChainRules.var"#times_pullback3#1330"{Int64, Int64, Int64}}, Zygote.var"#2763#back#609"{Zygote.var"#603#607"{Array{Float32, 4}, Tuple{Int64, Colon}}}}}, Zygote.var"#2029#back#213"{Zygote.var"#back#211"{8, 3, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}}}, Zygote.Pullback{Tuple{Dropout{Float64, Colon, TaskLocalRNG}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:rng, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, TaskLocalRNG}}, Zygote.var"#2013#back#204"{typeof(identity)}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:dims, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, Colon}}, Zygote.ZBack{ChainRules.var"#times_pullback2#1329"{Float64, Bool}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:dims,)}}, Tuple{Colon}}, Tuple{Zygote.var"#2220#back#315"{Zygote.Jnew{@NamedTuple{dims::Colon}, Nothing, true}}}}, Zygote.Pullback{Tuple{typeof(Flux._isactive), Dropout{Float64, Colon, TaskLocalRNG}, Array{Float32, 4}}, Any}, Zygote.var"#2180#back#30 ...
#     @ Zygote ~/.julia/packages/Zygote/jxHJc/src/compiler/interface2.jl:0
#  [23] #12
#     @ ./In[7]:6 [inlined]
#  [24] (::Zygote.Pullback{Tuple{var"#12#13"{Array{Float32, 4}, Array{Float32, 4}}, Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}}, Tuple{Zygote.Pullback{Tuple{Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:layers, Zygote.Context{false}, Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}, Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}}, Zygote.Pullback{Tuple{typeof(Flux._applychain), Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}, Array{Float32, 4}}, Tuple{Zygote.Pullback{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:σ, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, typeof(identity)}}, Zygote.Pullback{Tuple{typeof(NNlib.fast_act), typeof(identity), Matrix{Float32}}, Tuple{}}, Zygote.var"#3748#back#1183"{Zygote.var"#1177#1181"{Tuple{Matrix{Float32}, Vector{Float32}}}}, Zygote.var"#3892#back#1249"{Zygote.var"#1245#1248"}, Zygote.ZBack{Flux.var"#_size_check_pullback#210"{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}, Pair{Int64, Int64}}}}, Zygote.ZBack{ChainRules.var"#times_pullback#1464"{Matrix{Float32}, Matrix{Float32}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:bias, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Vector{Float32}}}, Zygote.Pullback{Tuple{typeof(Base.Broadcast.materialize), Matrix{Float32}}, Tuple{}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}}, Zygote.Pullback{Tuple{Type{Pair}, Int64, Int64}, Any}, Zygote.ZBack{ChainRules.var"#size_pullback#919"}, Zygote.ZBack{Flux.var"#187#188"}}}, Zygote.Pullback{Tuple{var"#4#7", Array{Float32, 4}}, Tuple{Zygote.ZBack{ChainRules.var"#times_pullback3#1330"{Int64, Int64, Int64}}, Zygote.var"#2763#back#609"{Zygote.var"#603#607"{Array{Float32, 4}, Tuple{Int64, Colon}}}}}, Zygote.var"#2029#back#213"{Zygote.var"#back#211"{8, 3, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}}}, Zygote.Pullback{Tuple{Dropout{Float64, Colon, TaskLocalRNG}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:rng, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, TaskLocalRNG}}, Zygote.var"#2013#back#204"{typeof(identity)}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:dims, Zygote.Context{false}, Dropout{Fl ...
#     @ Zygote ~/.julia/packages/Zygote/jxHJc/src/compiler/interface2.jl:0
#  [25] (::Zygote.var"#75#76"{Zygote.Pullback{Tuple{var"#12#13"{Array{Float32, 4}, Array{Float32, 4}}, Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}}, Tuple{Zygote.Pullback{Tuple{Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:layers, Zygote.Context{false}, Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}, Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}}, Zygote.Pullback{Tuple{typeof(Flux._applychain), Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}, Array{Float32, 4}}, Tuple{Zygote.Pullback{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:σ, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, typeof(identity)}}, Zygote.Pullback{Tuple{typeof(NNlib.fast_act), typeof(identity), Matrix{Float32}}, Tuple{}}, Zygote.var"#3748#back#1183"{Zygote.var"#1177#1181"{Tuple{Matrix{Float32}, Vector{Float32}}}}, Zygote.var"#3892#back#1249"{Zygote.var"#1245#1248"}, Zygote.ZBack{Flux.var"#_size_check_pullback#210"{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}, Pair{Int64, Int64}}}}, Zygote.ZBack{ChainRules.var"#times_pullback#1464"{Matrix{Float32}, Matrix{Float32}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:bias, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Vector{Float32}}}, Zygote.Pullback{Tuple{typeof(Base.Broadcast.materialize), Matrix{Float32}}, Tuple{}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:weight, Zygote.Context{false}, Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, Matrix{Float32}}}, Zygote.Pullback{Tuple{Type{Pair}, Int64, Int64}, Any}, Zygote.ZBack{ChainRules.var"#size_pullback#919"}, Zygote.ZBack{Flux.var"#187#188"}}}, Zygote.Pullback{Tuple{var"#4#7", Array{Float32, 4}}, Tuple{Zygote.ZBack{ChainRules.var"#times_pullback3#1330"{Int64, Int64, Int64}}, Zygote.var"#2763#back#609"{Zygote.var"#603#607"{Array{Float32, 4}, Tuple{Int64, Colon}}}}}, Zygote.var"#2029#back#213"{Zygote.var"#back#211"{8, 3, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}}}, Zygote.Pullback{Tuple{Dropout{Float64, Colon, TaskLocalRNG}, Array{Float32, 4}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:rng, Zygote.Context{false}, Dropout{Float64, Colon, TaskLocalRNG}, TaskLocalRNG}}, Zygote.var"#2013#back#204"{typeof(identity)}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:dims, Zygote.Context ...
#     @ Zygote ~/.julia/packages/Zygote/jxHJc/src/compiler/interface.jl:91
#  [26] withgradient(f::Function, args::Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}})
#     @ Zygote ~/.julia/packages/Zygote/jxHJc/src/compiler/interface.jl:0
#  [27] train_discriminator!(gen::Chain{Tuple{Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, BatchNorm{typeof(relu), Vector{Float32}, Float32, Vector{Float32}}, var"#8#10", ConvTranspose{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, BatchNorm{typeof(relu), Vector{Float32}, Float32, Vector{Float32}}, ConvTranspose{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, BatchNorm{typeof(relu), Vector{Float32}, Float32, Vector{Float32}}, ConvTranspose{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#9#11"}}, dscr::Chain{Tuple{Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#2#5", Dropout{Float64, Colon, TaskLocalRNG}, Conv{2, 4, typeof(identity), Array{Float32, 4}, Vector{Float32}}, var"#3#6", Dropout{Float64, Colon, TaskLocalRNG}, var"#4#7", Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}}}, x::Array{Float32, 4}, opt_dscr::@NamedTuple{layers::Tuple{@NamedTuple{σ::Tuple{}, weight::Optimisers.Leaf{Optimisers.Adam, Tuple{Array{Float32, 4}, Array{Float32, 4}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Optimisers.Adam, Tuple{Vector{Float32}, Vector{Float32}, Tuple{Float32, Float32}}}, stride::Tuple{Tuple{}, Tuple{}}, pad::NTuple{4, Tuple{}}, dilation::Tuple{Tuple{}, Tuple{}}, groups::Tuple{}}, Tuple{}, @NamedTuple{p::Tuple{}, dims::Tuple{}, active::Tuple{}, rng::Tuple{}}, @NamedTuple{σ::Tuple{}, weight::Optimisers.Leaf{Optimisers.Adam, Tuple{Array{Float32, 4}, Array{Float32, 4}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Optimisers.Adam, Tuple{Vector{Float32}, Vector{Float32}, Tuple{Float32, Float32}}}, stride::Tuple{Tuple{}, Tuple{}}, pad::NTuple{4, Tuple{}}, dilation::Tuple{Tuple{}, Tuple{}}, groups::Tuple{}}, Tuple{}, @NamedTuple{p::Tuple{}, dims::Tuple{}, active::Tuple{}, rng::Tuple{}}, Tuple{}, @NamedTuple{weight::Optimisers.Leaf{Optimisers.Adam, Tuple{Matrix{Float32}, Matrix{Float32}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Optimisers.Adam, Tuple{Vector{Float32}, Vector{Float32}, Tuple{Float32, Float32}}}, σ::Tuple{}}}}, hparams::HyperParams)
#     @ Main ./In[7]:5
#  [28] train(; kws::@Kwargs{})
#     @ Main ./In[9]:36
#  [29] train()
#     @ Main ./In[9]:1
#  [30] top-level scope
#     @ In[10]:7

# %% [markdown]
# # References
#
# - [ ] [Deep Convolutional GAN (DC-GAN)](https://github.com/FluxML/model-zoo/tree/master/vision/dcgan_mnist)
